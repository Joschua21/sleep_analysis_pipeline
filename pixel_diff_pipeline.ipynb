# %%
import pixel_diff_utils as pdu
import os
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
from tqdm import tqdm
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget
input_dir=r"C:\Users\Experiment\Projects\video_conversions\subjects\AV023\2022-12-11_2\DLC"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
results = pdu.analyze_and_plot_video(
    input_dir=input_dir,
    filename=None,  # Auto-find video with preference for MJ2
    smooth_window=15,
    y_min=400000, 
    y_max=1200000,
    sleep_threshold=675000,
    plot_type='smoothed' # 'raw' or 'smoothed'
)
# Out:
# Using MJ2 file: 2022-12-11_2_AV023_sideCam.mj2
# Input video: C:\Users\Experiment\Projects\video_conversions\subjects\AV023\2022-12-11_2\DLC\2022-12-11_2_AV023_sideCam.mj2
# Output directory: C:\Users\Experiment\Projects\video_conversions\subjects\AV023\2022-12-11_2\DLC\pixel_difference
# Video properties: 110300 frames, 60.15081967213115 fps, 640x512 pixels
# Video duration: 1833.72 seconds
# Calculating frame differences...
# 100%|██████████| 110299/110299 [05:57<00:00, 308.43it/s]
# Processed 110299 frame differences
# Detected 12 potential black frames
# Black frames found at frame indices: [866 867 868 869 870 871 872 873 874 875 876 877]
# Removing 23 frame transitions due to black frames (including buffer)
# Found 2 continuous valid segments for smoothing
# Saved difference data to: C:\Users\Experiment\Projects\video_conversions\subjects\AV023\2022-12-11_2\DLC\pixel_difference\2022-12-11_2_AV023_sideCam_pixel_differences.csv
#
# Motion Analysis Summary:
#   Mean motion: 644869.47
#   Max motion: 2512548.13
#   Mean rate of change: 11348.58
#   Max rate of change: 230349.27
#   Black frames detected: 12
#   Transitions affected by black frames: 23
# Saved figure to: C:\Users\Experiment\Projects\video_conversions\subjects\AV023\2022-12-11_2\DLC\pixel_difference\2022-12-11_2_AV023_sideCam_smoothed_pixel_diff_y_400000_1200000.png
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
y_min = 400000
y_max = 2500000
sleep_threshold = 580000
pdu.reuse_previous_analysis(
    y_min=y_min,
    y_max=y_max,
    sleep_threshold=sleep_threshold,
    plot_type='smoothed', # 'raw' or 'smoothed'
    input_dir=input_dir,
)
# Out:
# Found analysis file: C:\Users\Experiment\Projects\video_conversions\subjects\AV023\2022-12-11_2\DLC\pixel_difference\2022-12-11_2_AV023_sideCam_pixel_differences.csv
# Loading analysis from C:\Users\Experiment\Projects\video_conversions\subjects\AV023\2022-12-11_2\DLC\pixel_difference\2022-12-11_2_AV023_sideCam_pixel_differences.csv...
# Successfully loaded analysis data with 110299 frames
# Saved figure to: C:\Users\Experiment\Projects\video_conversions\subjects\AV023\2022-12-11_2\DLC\pixel_difference\2022-12-11_2_AV023_sideCam_smoothed_pixel_diff_y_400000_2500000.png
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 'C:\\Users\\Experiment\\Projects\\video_conversions\\subjects\\AV023\\2022-12-11_2\\DLC\\pixel_difference\\2022-12-11_2_AV023_sideCam_smoothed_pixel_diff_y_400000_2500000.png'

# %%
pdu.interactive_sleep_selection(
    input_dir=input_dir,
    y_min=y_min,
    y_max=y_max,
    sleep_threshold=sleep_threshold,
    min_sleep_duration=15,
    plot_type='smoothed', # 'raw' or 'smoothed'
    save_file='sleep_times.csv',
)
# Out:
# Found analysis file: C:\Users\Experiment\Projects\video_conversions\subjects\AV023\2022-12-11_2\DLC\pixel_difference\2022-12-11_2_AV023_sideCam_pixel_differences.csv
# Loading analysis from C:\Users\Experiment\Projects\video_conversions\subjects\AV023\2022-12-11_2\DLC\pixel_difference\2022-12-11_2_AV023_sideCam_pixel_differences.csv...
# Successfully loaded analysis data with 110299 frames
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Detected Sleep Periods:
# --------------------------------------------------
# 1. 416.4s - 451.9s (35.6s)
# 2. 464.2s - 482.5s (18.4s)
# 3. 521.2s - 542.0s (20.9s)
# 4. 583.2s - 612.7s (29.5s)
# 5. 724.5s - 744.9s (20.4s)
# 6. 745.1s - 800.7s (55.6s)
# 7. 834.2s - 865.0s (30.8s)
# 8. 889.9s - 944.8s (54.8s)
# 9. 1036.3s - 1053.2s (16.9s)
# 10. 1092.6s - 1116.5s (23.9s)
# 11. 1277.8s - 1346.0s (68.3s)
# --------------------------------------------------
#
# Saved 11 selected sleep periods to: C:\Users\Experiment\Projects\video_conversions\subjects\AV023\2022-12-11_2\DLC\pixel_difference\sleep_times.csv
#
# Selected periods:
# 1. 416.4s - 451.9s (35.6s)
# 2. 464.2s - 482.5s (18.4s)
# 3. 521.2s - 542.0s (20.9s)
# 4. 583.2s - 612.7s (29.5s)
# 5. 724.5s - 744.9s (20.4s)
# 6. 745.1s - 800.7s (55.6s)
# 7. 834.2s - 865.0s (30.8s)
# 8. 889.9s - 944.8s (54.8s)
# 9. 1036.3s - 1053.2s (16.9s)
# 10. 1092.6s - 1116.5s (23.9s)
# 11. 1277.8s - 1346.0s (68.3s)
# Saved final plot to: C:\Users\Experiment\Projects\video_conversions\subjects\AV023\2022-12-11_2\DLC\pixel_difference\2022-12-11_2_AV023_sideCam_smoothed_selected_sleep_y_400000_2500000.png
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 'C:\\Users\\Experiment\\Projects\\video_conversions\\subjects\\AV023\\2022-12-11_2\\DLC\\pixel_difference\\sleep_times.csv'
