# %%
import pixel_diff_utils as pdu
import os
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
from tqdm import tqdm
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget
input_dir=r"C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-08-08_2\DLC"

# %%
results = pdu.analyze_and_plot_video(
    input_dir=input_dir,
    filename=None,  # Auto-find video with preference for MJ2
    smooth_window=15,
    y_min=500000, 
    y_max=900000,
    sleep_threshold=625000,
    plot_type='smoothed' # 'raw' or 'smoothed'
)
# Out:
# Using MJ2 file: 2023-08-08_2_AV049_topCam.mj2
# Input video: C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-08-08_2\DLC\2023-08-08_2_AV049_topCam.mj2
# Output directory: C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-08-08_2\DLC\pixel_difference
# Video properties: 163800 frames, 60.0 fps, 640x512 pixels
# Video duration: 2730.00 seconds
# Calculating frame differences...
# 100%|██████████| 163799/163799 [07:32<00:00, 361.72it/s]
# Processed 163799 frame differences
# Detected 10 potential black frames
# Black frames found at frame indices: [560 561 562 563 564 565 566 567 568 569]
# Removing 21 frame transitions due to black frames (including buffer)
# Found 2 continuous valid segments for smoothing
# Saved difference data to: C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-08-08_2\DLC\pixel_difference\2023-08-08_2_AV049_topCam_pixel_differences.csv
#
# Motion Analysis Summary:
#   Mean motion: 629205.72
#   Max motion: 840893.33
#   Mean rate of change: 738.27
#   Max rate of change: 47347.93
#   Black frames detected: 10
#   Transitions affected by black frames: 21
# Saved figure to: C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-08-08_2\DLC\pixel_difference\2023-08-08_2_AV049_topCam_smoothed_pixel_diff_y_500000_900000.png

# %%
pdu.reuse_previous_analysis(
    y_min=500000,
    y_max=900000,
    sleep_threshold=620000,
    plot_type='smoothed', # 'raw' or 'smoothed'
    input_dir=input_dir,
)
# Out:
# Found analysis file: C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-08-08_2\DLC\pixel_difference\2023-08-08_2_AV049_topCam_pixel_differences.csv
# Loading analysis from C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-08-08_2\DLC\pixel_difference\2023-08-08_2_AV049_topCam_pixel_differences.csv...
# Successfully loaded analysis data with 163799 frames
# Saved figure to: C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-08-08_2\DLC\pixel_difference\2023-08-08_2_AV049_topCam_smoothed_pixel_diff_y_500000_900000.png
# 'C:\\Users\\Experiment\\Projects\\video_conversions\\subjects\\AV049\\2023-08-08_2\\DLC\\pixel_difference\\2023-08-08_2_AV049_topCam_smoothed_pixel_diff_y_500000_900000.png'

# %%
pdu.interactive_sleep_selection(
    input_dir=input_dir,
    y_min=500000, 
    y_max=900000,
    sleep_threshold=625000,
    min_sleep_duration=15,
    plot_type='smoothed', # 'raw' or 'smoothed'
    save_file='sleep_times.csv',
)
# Out:
# Found analysis file: C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-08-08_2\DLC\pixel_difference\2023-08-08_2_AV049_topCam_pixel_differences.csv
# Loading analysis from C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-08-08_2\DLC\pixel_difference\2023-08-08_2_AV049_topCam_pixel_differences.csv...
# Successfully loaded analysis data with 163799 frames
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Detected Sleep Periods:
# --------------------------------------------------
# 1. 435.1s - 465.9s (30.8s)
# 2. 736.5s - 900.2s (163.7s)
# 3. 1876.0s - 1913.3s (37.3s)
# 4. 1916.3s - 1952.5s (36.1s)
# 5. 1953.3s - 2020.8s (67.5s)
# 6. 2025.4s - 2070.6s (45.2s)
# 7. 2072.8s - 2390.7s (317.8s)
# 8. 2411.7s - 2507.0s (95.3s)
# 9. 2507.3s - 2623.2s (115.9s)
# 10. 2623.3s - 2730.0s (106.7s)
# --------------------------------------------------
#
# Saved 8 selected sleep periods to: C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-08-08_2\DLC\pixel_difference\sleep_times.csv
#
# Selected periods:
# 1. 1876.0s - 1913.3s (37.3s)
# 2. 1916.3s - 1952.5s (36.1s)
# 3. 1953.3s - 2020.8s (67.5s)
# 4. 2025.4s - 2070.6s (45.2s)
# 5. 2072.8s - 2390.7s (317.8s)
# 6. 2411.7s - 2507.0s (95.3s)
# 7. 2507.3s - 2623.2s (115.9s)
# 8. 2623.3s - 2730.0s (106.7s)
# Saved final plot to: C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-08-08_2\DLC\pixel_difference\2023-08-08_2_AV049_topCam_smoothed_selected_sleep_y_500000_900000.png
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 'C:\\Users\\Experiment\\Projects\\video_conversions\\subjects\\AV049\\2023-08-08_2\\DLC\\pixel_difference\\sleep_times.csv'
