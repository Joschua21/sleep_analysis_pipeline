# %%
import pixel_diff_utils as pdu
import os
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
from tqdm import tqdm
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget
input_dir=r"C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-07-27_2\DLC"

# %%
results = pdu.analyze_and_plot_video(
    input_dir=input_dir,
    filename=None,  # Auto-find video with preference for MJ2
    smooth_window=15,
    y_min=600000, 
    y_max=900000,
    sleep_threshold=675000,
    plot_type='smoothed' # 'raw' or 'smoothed'
)
# Out:
# Using MJ2 file: 2023-07-27_2_AV049_topCam.mj2
# Input video: C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-07-27_2\DLC\2023-07-27_2_AV049_topCam.mj2
# Output directory: C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-07-27_2\DLC\pixel_difference
# Video properties: 144500 frames, 60.0 fps, 640x512 pixels
# Video duration: 2408.33 seconds
# Calculating frame differences...
# 100%|██████████| 144499/144499 [06:48<00:00, 353.48it/s]
# Processed 144499 frame differences
# Detected 20 potential black frames
# Black frames found at frame indices: [   555    556    557    558    559    560    561    562    563    564
#  144260 144261 144262 144263 144264 144265 144266 144267 144268 144269]
# Removing 42 frame transitions due to black frames (including buffer)
# Found 3 continuous valid segments for smoothing
# Saved difference data to: C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-07-27_2\DLC\pixel_difference\2023-07-27_2_AV049_topCam_pixel_differences.csv
#
# Motion Analysis Summary:
#   Mean motion: 651851.44
#   Max motion: 790108.00
#   Mean rate of change: 697.22
#   Max rate of change: 46705.87
#   Black frames detected: 20
#   Transitions affected by black frames: 42
# Saved figure to: C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-07-27_2\DLC\pixel_difference\2023-07-27_2_AV049_topCam_smoothed_pixel_diff_y_600000_900000.png
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pdu.reuse_previous_analysis(
    y_min=600000,
    y_max=850000,
    sleep_threshold=660000,
    plot_type='smoothed', # 'raw' or 'smoothed'
    input_dir=input_dir,
)
# Out:
# Found analysis file: C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-07-27_2\DLC\pixel_difference\2023-07-27_2_AV049_topCam_pixel_differences.csv
# Loading analysis from C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-07-27_2\DLC\pixel_difference\2023-07-27_2_AV049_topCam_pixel_differences.csv...
# Successfully loaded analysis data with 144499 frames
# Saved figure to: C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-07-27_2\DLC\pixel_difference\2023-07-27_2_AV049_topCam_smoothed_pixel_diff_y_600000_850000.png
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 'C:\\Users\\Experiment\\Projects\\video_conversions\\subjects\\AV049\\2023-07-27_2\\DLC\\pixel_difference\\2023-07-27_2_AV049_topCam_smoothed_pixel_diff_y_600000_850000.png'

# %%
pdu.interactive_sleep_selection(
    input_dir=input_dir,
    y_min=600000, 
    y_max=850000,
    sleep_threshold=660000,
    min_sleep_duration=15,
    plot_type='smoothed', # 'raw' or 'smoothed'
    save_file='sleep_times.csv',
)
# Out:
# Found analysis file: C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-07-27_2\DLC\pixel_difference\2023-07-27_2_AV049_topCam_pixel_differences.csv
# Loading analysis from C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-07-27_2\DLC\pixel_difference\2023-07-27_2_AV049_topCam_pixel_differences.csv...
# Successfully loaded analysis data with 144499 frames
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Detected Sleep Periods:
# --------------------------------------------------
# 1. 243.7s - 267.2s (23.5s)
# 2. 360.7s - 376.7s (16.0s)
# 3. 744.8s - 781.1s (36.4s)
# 4. 781.8s - 804.2s (22.3s)
# 5. 804.3s - 922.2s (118.0s)
# 6. 931.6s - 954.7s (23.1s)
# 7. 956.4s - 1029.8s (73.4s)
# 8. 1042.4s - 1108.7s (66.2s)
# 9. 1118.5s - 1149.6s (31.1s)
# 10. 1167.8s - 1192.9s (25.0s)
# 11. 1204.7s - 1281.8s (77.1s)
# 12. 1284.2s - 1327.0s (42.8s)
# 13. 1328.3s - 1481.8s (153.5s)
# 14. 1491.8s - 1513.7s (21.8s)
# 15. 1547.2s - 1770.6s (223.5s)
# 16. 1936.7s - 1951.9s (15.2s)
# 17. 1964.7s - 1989.7s (25.0s)
# 18. 1989.9s - 2047.4s (57.5s)
# 19. 2064.1s - 2238.9s (174.7s)
# 20. 2250.6s - 2404.2s (153.6s)
# --------------------------------------------------
#
# Saved 17 selected sleep periods to: C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-07-27_2\DLC\pixel_difference\sleep_times.csv
#
# Selected periods:
# 1. 744.8s - 781.1s (36.4s)
# 2. 781.8s - 804.2s (22.3s)
# 3. 804.3s - 922.2s (118.0s)
# 4. 931.6s - 954.7s (23.1s)
# 5. 956.4s - 1029.8s (73.4s)
# 6. 1042.4s - 1108.7s (66.2s)
# 7. 1167.8s - 1192.9s (25.0s)
# 8. 1204.7s - 1281.8s (77.1s)
# 9. 1284.2s - 1327.0s (42.8s)
# 10. 1328.3s - 1481.8s (153.5s)
# 11. 1491.8s - 1513.7s (21.8s)
# 12. 1547.2s - 1770.6s (223.5s)
# 13. 1936.7s - 1951.9s (15.2s)
# 14. 1964.7s - 1989.7s (25.0s)
# 15. 1989.9s - 2047.4s (57.5s)
# 16. 2064.1s - 2238.9s (174.7s)
# 17. 2250.6s - 2404.2s (153.6s)
# Saved final plot to: C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-07-27_2\DLC\pixel_difference\2023-07-27_2_AV049_topCam_smoothed_selected_sleep_y_600000_850000.png
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 'C:\\Users\\Experiment\\Projects\\video_conversions\\subjects\\AV049\\2023-07-27_2\\DLC\\pixel_difference\\sleep_times.csv'
