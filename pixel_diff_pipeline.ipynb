# %%
import pixel_diff_utils as pdu
import os
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
from tqdm import tqdm
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget
input_dir=r"C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-07-31_3\DLC"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
results = pdu.analyze_and_plot_video(
    input_dir=input_dir,
    filename=None,  # Auto-find video with preference for MJ2
    smooth_window=15,
    y_min=400000, 
    y_max=1200000,
    sleep_threshold=675000,
    plot_type='smoothed' # 'raw' or 'smoothed'
)
# Out:
# Using MJ2 file: 2023-07-31_3_AV049_topCam.mj2
# Input video: C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-07-31_3\DLC\2023-07-31_3_AV049_topCam.mj2
# Output directory: C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-07-31_3\DLC\pixel_difference
# Video properties: 149900 frames, 60.0 fps, 640x512 pixels
# Video duration: 2498.33 seconds
# Calculating frame differences...
# 100%|██████████| 149899/149899 [07:09<00:00, 348.82it/s]
# Processed 149899 frame differences
# Detected 20 potential black frames
# Black frames found at frame indices: [   813    814    815    816    817    818    819    820    821    822
#  149622 149623 149624 149625 149626 149627 149628 149629 149630 149631]
# Removing 42 frame transitions due to black frames (including buffer)
# Found 3 continuous valid segments for smoothing
# Saved difference data to: C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-07-31_3\DLC\pixel_difference\2023-07-31_3_AV049_topCam_pixel_differences.csv
#
# Motion Analysis Summary:
#   Mean motion: 655672.69
#   Max motion: 948156.93
#   Mean rate of change: 697.73
#   Max rate of change: 15464.93
#   Black frames detected: 20
#   Transitions affected by black frames: 42
# Saved figure to: C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-07-31_3\DLC\pixel_difference\2023-07-31_3_AV049_topCam_smoothed_pixel_diff_y_400000_1200000.png
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
y_min = 625000
y_max = 950000
sleep_threshold = 645000
pdu.reuse_previous_analysis(
    y_min=y_min,
    y_max=y_max,
    sleep_threshold=sleep_threshold,
    plot_type='smoothed', # 'raw' or 'smoothed'
    input_dir=input_dir,
)
# Out:
# Found analysis file: C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-07-31_3\DLC\pixel_difference\2023-07-31_3_AV049_topCam_pixel_differences.csv
# Loading analysis from C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-07-31_3\DLC\pixel_difference\2023-07-31_3_AV049_topCam_pixel_differences.csv...
# Successfully loaded analysis data with 149899 frames
# Saved figure to: C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-07-31_3\DLC\pixel_difference\2023-07-31_3_AV049_topCam_smoothed_pixel_diff_y_625000_950000.png
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 'C:\\Users\\Experiment\\Projects\\video_conversions\\subjects\\AV049\\2023-07-31_3\\DLC\\pixel_difference\\2023-07-31_3_AV049_topCam_smoothed_pixel_diff_y_625000_950000.png'

# %%
pdu.interactive_sleep_selection(
    input_dir=input_dir,
    y_min=y_min,
    y_max=y_max,
    sleep_threshold=sleep_threshold,
    min_sleep_duration=15,
    plot_type='smoothed', # 'raw' or 'smoothed'
    save_file='sleep_times.csv',
)
# Out:
# Found analysis file: C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-07-31_3\DLC\pixel_difference\2023-07-31_3_AV049_topCam_pixel_differences.csv
# Loading analysis from C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-07-31_3\DLC\pixel_difference\2023-07-31_3_AV049_topCam_pixel_differences.csv...
# Successfully loaded analysis data with 149899 frames
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Detected Sleep Periods:
# --------------------------------------------------
# 1. 1705.4s - 1831.5s (126.2s)
# 2. 1840.3s - 2053.0s (212.8s)
# 3. 2082.2s - 2171.1s (88.9s)
# 4. 2192.6s - 2294.4s (101.8s)
# 5. 2302.5s - 2480.9s (178.4s)
# --------------------------------------------------
#
# Saved 5 selected sleep periods to: C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-07-31_3\DLC\pixel_difference\sleep_times.csv
#
# Selected periods:
# 1. 1705.4s - 1831.5s (126.2s)
# 2. 1840.3s - 2053.0s (212.8s)
# 3. 2082.2s - 2171.1s (88.9s)
# 4. 2192.6s - 2294.4s (101.8s)
# 5. 2302.5s - 2480.9s (178.4s)
# Saved final plot to: C:\Users\Experiment\Projects\video_conversions\subjects\AV049\2023-07-31_3\DLC\pixel_difference\2023-07-31_3_AV049_topCam_smoothed_selected_sleep_y_625000_950000.png
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 'C:\\Users\\Experiment\\Projects\\video_conversions\\subjects\\AV049\\2023-07-31_3\\DLC\\pixel_difference\\sleep_times.csv'
